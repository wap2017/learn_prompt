# %%
import os
import openai

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key = os.getenv("OPEN_API_KEY")

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message["content"]

# %%
get_completion("hello")
# Out:
# 'Hello! How can I assist you today?'

# %%
prompt = f"""
请帮我把prompt这个单词翻译成中文
"""
get_completion(prompt)
# Out:
# 'prompt 的中文翻译是“提示”或“促使”。'

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/opt/python@3.9/bin/python3.9

# %%
prompt = f"""
我最近在学习英语，想要记住prompt这个单词，你有什么比较好的技巧能让我记住这个单词吗？
"""
get_completion(prompt)
# Out:
# '当记忆一个单词时，可以尝试以下技巧：\n\n1. 创造联想：将单词与你熟悉的事物或场景联系起来，比如将prompt联想成“提示”，表示提醒或提示的意思。\n\n2. 制作记忆卡片：在一张卡片上写下prompt和它的意思，然后反复阅读和复习这张卡片。\n\n3. 使用单词：尽量在日常生活中使用这个单词，比如在对话中或写作中，这样可以帮助你更好地记住它。\n\n4. 创造关联：将prompt与其他单词或短语联系起来，比如prompt response（迅速的回应）或prompt action（迅速的行动），这样可以帮助你更好地理解和记忆这个单词的用法。\n\n希望这些技巧能帮助你更好地记住prompt这个单词！加油！'

# %%
prompt = f"""
我最近在学习英语，想要记住prompt这个单词，你能帮我找到它的发音吗？
"""
get_completion(prompt)
# Out:
# '当然可以！"prompt" 这个单词的发音是 /prɒmpt/。希望对你有帮助！如果你还有其他问题，欢迎随时问我。'

# %%
prompt = f"""
帮我生成10个汉子词组，要求每个词是3个汉字，并且3个汉字的拼音各自是以mpt三个声母开头的
"""
get_completion(prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7402de047d8e> in <module>
#       2 帮我生成10个汉子词组，要求每个词是3个汉字，并且3个汉字的拼音各自是以mpt三个声母开头的
#       3 """
# ----> 4 get_completion(prompt)
#
# NameError: name 'get_completion' is not defined

# %%
exp = "(1+2)+(3+4)*5"

prompt = f"""
你的任务是模拟一个计算器，我会给你一个表达式，你需要计算出结果
我给你的表达式在下面3个反引号里面

如果表达式不能计算出准确的值，请直接返回”输入有误”

比如我输入的表达式是5+2*5+3, 你应该返回18
比如我输入的表达式是3+2i，你应该返回输入有误


你应该按如下步骤计算结果而不是猜测答案：

步骤一：有括号先算括号里面的, 得到中间表达式 middle_exp1
步骤二：接着算乘法和除法，得到中间表达式 middle_exp2
步骤三：最后再算加法和减法，得到结果 res

需要把exp, middle_exp1, middle_exp2, res，remark三个字段按json格式返回
另外，你需要在remark字段注明结果来自LLM，仅供参考

```
{exp}
```
"""


print(get_completion(prompt))
# Out:
# {
#     "exp": "(1+2)+(3+4)*5",
#     "middle_exp1": "(1+2)+(7)*5",
#     "middle_exp2": "(1+2)+35",
#     "res": "38",
#     "remark": "结果来自LLM，仅供参考"
# }

# %%
# 概括
prompt = f"""
你的任务是概括文本，我将给你一段长文案，你需要用一句话概括

我给你的长文本包含在反引号里面，要求不能多于50个字概括

```
PUA，即Pick-Up Artist，是一种以追求异性为目的的社交技巧和心理战术。PUA的目的是通过一系列技巧和策略来吸引异性，让对方对自己产生兴趣。然而，PUA的方法往往是建立在欺骗和操纵的基础上，对他人造成伤害。因此，识别和应对PUA是非常重要的。

首先，要识别PUA的行为。PUA常常使用一些心理战术和技巧来吸引异性，比如夸大自己的成就、使用搭讪术、制造情感共鸣等。他们往往会对目标进行心理分析，找出对方的弱点，然后利用这些弱点来操纵对方。他们可能会使用一些虚假的承诺和夸大其词的表达来迷惑对方，让对方产生错误的印象。

其次，要学会应对PUA的行为。当你发现有人在使用PUA技巧来接近你时，首先要保持冷静，不要被对方的花言巧语所迷惑。要学会辨别对方的真实意图，不要轻易相信对方所说的一切。如果对方的行为让你感到不舒服或不安全，要及时采取行动，保护自己的权益。

另外，要学会拒绝PUA的行为。当你发现有人在使用PUA技巧来接近你时，要坚决拒绝对方的邀约和搭讪。不要让对方得逞，让他们知道你不是好欺负的对象。要坚守自己的底线，不要被对方的花言巧语所动摇。如果对方的行为让你感到不舒服或不安全，要及时向他人求助，寻求帮助。

最后，要学会保护自己。在社交场合中，要时刻保持警惕，不要轻易相信陌生人。要学会辨别对方的真实意图，不要被对方的表面行为所迷惑。如果对方的行为让你感到不舒服或不安全，要及时采取行动，保护自己的权益。要学会拒绝不良行为，坚守自己的底线，不让任何人侵犯自己的权益。

总之，识别和应对PUA是非常重要的。要学会辨别对方的真实意图，保持冷静，不要被对方的花言巧语所迷惑。要学会拒绝不良行为，保护自己的权益。只有这样，我们才能在社交场合中保护自己，远离不良影响。
"""
print(get_completion(prompt))
# Out:
# 识别和拒绝PUA，保护自己免受欺骗和操纵。

# %%
# 推断
prompt = f"""
你的任务是识别出评论里面的情绪，从评论列表中判断用户此时是否处于愤怒状态。
我给你的评论列表会放在三个反引号之中，每一行表示一条评论

结果需要用Json格式返回，字段包括
comment: <评论>
is_angry: <True/False>

```
1. 无语了，买的椅子到货的时候断了一只脚，联系客服说不能退，大家千万不要踩坑
2. 种草，这家店的衣服简直了！
3. 妈的，这都什么商品啊，完全就是个垃圾，退货！退货！退货！

```
"""
print(get_completion(prompt))
# Out:
# {
#     "results": [
#         {
#             "comment": "无语了，买的椅子到货的时候断了一只脚，联系客服说不能退，大家千万不要踩坑",
#             "is_angry": true
#         },
#         {
#             "comment": "种草，这家店的衣服简直了！",
#             "is_angry": false
#         },
#         {
#             "comment": "妈的，这都什么商品啊，完全就是个垃圾，退货！退货！退货！",
#             "is_angry": true
#         }
#     ]
# }

# %%
# 翻译
prompt = f"""
你的任务是翻译我的中文到英语，我给你的中文在三个反引号里面

```
大家好，我是辣鱼，是长期主义践行者
```
请翻译并输出json格式的答案


"""
print(get_completion(prompt))
# Out:
# {
#   "translation": "Hello everyone, I am Spicy Fish, a practitioner of long-termism."
# }

# %%
# 扩展
prompt = f"""
请你写一篇800字左右的文章，内容是怎么识别和应对PUA
"""
print(get_completion(prompt))
# Out:
# PUA，即Pick-Up Artist，是一种以追求异性为目的的社交技巧和心理战术。PUA的目的是通过一系列技巧和策略来吸引异性，让对方对自己产生兴趣。然而，PUA的方法往往是建立在欺骗和操纵的基础上，对他人造成伤害。因此，识别和应对PUA是非常重要的。
#
# 首先，要识别PUA的行为。PUA常常使用一些心理战术和技巧来吸引异性，比如夸大自己的成就、使用搭讪术、制造情感共鸣等。他们往往会对目标进行心理分析，找出对方的弱点，然后利用这些弱点来操纵对方。他们可能会使用一些虚假的承诺和夸大其词的表达来迷惑对方，让对方产生错误的印象。
#
# 其次，要学会应对PUA的行为。当你发现有人在使用PUA技巧来接近你时，首先要保持冷静，不要被对方的花言巧语所迷惑。要学会辨别对方的真实意图，不要轻易相信对方所说的一切。如果对方的行为让你感到不舒服或不安全，要及时采取行动，保护自己的权益。
#
# 另外，要学会拒绝PUA的行为。当你发现有人在使用PUA技巧来接近你时，要坚决拒绝对方的邀约和搭讪。不要让对方得逞，让他们知道你不是好欺负的对象。要坚守自己的底线，不要被对方的花言巧语所动摇。如果对方的行为让你感到不舒服或不安全，要及时向他人求助，寻求帮助。
#
# 最后，要学会保护自己。在社交场合中，要时刻保持警惕，不要轻易相信陌生人。要学会辨别对方的真实意图，不要被对方的表面行为所迷惑。如果对方的行为让你感到不舒服或不安全，要及时采取行动，保护自己的权益。要学会拒绝不良行为，坚守自己的底线，不让任何人侵犯自己的权益。
#
# 总之，识别和应对PUA是非常重要的。要学会辨别对方的真实意图，保持冷静，不要被对方的花言巧语所迷惑。要学会拒绝不良行为，保护自己的权益。只有这样，我们才能在社交场合中保护自己，远离不良影响。

# %%
def get_completion_from_message(messages, model="gpt-3.5-turbo"):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7,
    )
    return response.choices[0].message["content"]

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''

    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_message(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))
 
    return pn.Column(*panels)

# %%
import panel as pn
pn.extension()

panels  = []
context = [
    {'role': 'system', 'content': '你是一个心理咨询师'},
]
inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
     inp,
     pn.Row(button_conversation),
     pn.panel(interactive_conversation, loading_indicator=True, height=300)   
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d1355ee5-1289-4562-8dae-ae74282e4580'>
#   <div id="c9b63573-97c9-4057-bb96-844d5b2b0e94" data-root-id="d1355ee5-1289-4562-8dae-ae74282e4580" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
